# %% [markdown]
# This assignment is for visualization using matplotlib:
#
# data to use:
#
# url=https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv
#
# titanic = pd.read_csv(url)
#
# Charts to plot:
# 1. Create a pie chart presenting the male/female proportion
# 2. Create a scatterplot with the Fare paid and the Age, differ the plot color by gender

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
url='https://raw.githubusercontent.com/Geoyi/Cleaning-Titanic-Data/master/titanic_original.csv'
titanic=pd.read_csv(url)
titanic.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0     1.0       1.0                    Allen, Miss. Elisabeth Walton  female
# 1     1.0       1.0                   Allison, Master. Hudson Trevor    male
# 2     1.0       0.0                     Allison, Miss. Helen Loraine  female
# 3     1.0       0.0             Allison, Mr. Hudson Joshua Creighton    male
# 4     1.0       0.0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000    0.0    0.0   24160  211.3375       B5        S    2    NaN
# 1   0.9167    1.0    2.0  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000    1.0    2.0  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
cnt=titanic['sex'].value_counts()
cnt.plot.pie(figsize = (5,5),textprops={'fontsize': 15},autopct='%1.1f%%',startangle=90)
plt.title('Male/Female proportion',fontsize=20)
titanic['sex'].fillna('male', inplace = True)

# %% [markdown]
# Scipy:
# We have the min and max temperatures in a city In India for each months of the year.
# We would like to find a function to describe this and show it graphically, the dataset
# given below.
#
# Task:
# 1. fitting it to the periodic function
# 2. plot the fit
#
# Data
#
# Max = 39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25
#
# Min = 21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18

# %%
import numpy as np
import matplotlib.pyplot as plt

maxtemp = np.array([39, 41, 43, 47, 49, 51, 45, 38, 37, 29, 27, 25])
mintemp = np.array([21, 23, 27, 28, 32, 35, 31, 28, 21, 19, 17, 18])

month = np.arange(0,12)
plt.plot(month, maxtemp,'go')
plt.plot(month, mintemp,'bo')
plt.xlabel('Month')
plt.ylabel('Min & Max Temperature')
# Out:
# Text(0, 0.5, 'Min & Max Temperature')

# %%
from scipy import optimize
def Temp(month, upper, lower, offset):
    return (upper + lower * np.cos((month + offset) * 2 * np.pi / month.max()))

# opt,cov = optimize.curve_fit( func , xdata ,ydata ,boundary )
# opt - Optimal values for the parameters so that the sum of the squared residuals of [f(xdata, *opt) - ydata] is minimized.
# cov - covariance of opt


max_opt, max_cov = optimize.curve_fit(Temp,month,maxtemp, [20, 10, 0])
min_opt, min_cov = optimize.curve_fit(Temp,month,mintemp, [-40, 20, 0])

# %%
days = np.linspace(0, 12, num=365)

plt.figure()

plt.plot(month, maxtemp, 'go')
plt.plot(days, Temp(days, *max_opt), 'r-')

plt.plot(month, mintemp, 'bo')
plt.plot(days, Temp(days, *min_opt), 'm-')

plt.title('Temperature Periodic Function',fontsize=20)
plt.xlabel('Month',fontsize=15)
plt.ylabel('Temperature in ($^\circ$C)',fontsize=15)


plt.show()
